# %%
import keypoint_moseq as kpms
import jax
from jax_moseq.utils import set_mixed_map_iters
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
MODE = "dannce"   # "dannce" or "sleap"
PROJECT_DIR = "/mnt/d/Project/Keypoint-Moseq/"
KEYPOINT_DATA = "/mnt/d/Project/Keypoint-Moseq/"
KAPPA = 6
N_MODELS = 5

# %%
config = lambda: kpms.load_config(PROJECT_DIR)
coordinates, confidences, bodyparts = kpms.load_keypoints(KEYPOINT_DATA, MODE)

# format data for modeling
data, metadata = kpms.format_data(coordinates, confidences, **config())

pca = kpms.load_pca(PROJECT_DIR)
set_mixed_map_iters(4)

# initialize the model
prefix = 'my_models'

ar_only_kappa = 10**KAPPA
num_ar_iters = 50

full_model_kappa = 10**(KAPPA-1)
num_full_iters = 500
# Out:
# Loading keypoints: 100%|██████████████████| 4/4 [00:00<00:00, 20.04it/s]

# %%
for restart in range(N_MODELS):
    print(f"Fitting model {restart}")
    model_name = f'{prefix}-{restart}'

    model = kpms.init_model(
        data, pca=pca, **config(), seed=jax.random.PRNGKey(restart)
    )

    # stage 1: fit the model with AR only
    model = kpms.update_hypparams(model, kappa=ar_only_kappa)
    model = kpms.fit_model(
        model,
        data,
        metadata,
        PROJECT_DIR,
        model_name,
        ar_only=True,
        num_iters=num_ar_iters
    )[0]

    # stage 2: fit the full model
    model = kpms.update_hypparams(model, kappa=full_model_kappa)
    kpms.fit_model(
        model,
        data,
        metadata,
        PROJECT_DIR,
        model_name,
        ar_only=False,
        start_iter=num_ar_iters,
        num_iters=num_full_iters
    )

    kpms.reindex_syllables_in_checkpoint(PROJECT_DIR, model_name);
    model, data, metadata, current_iter = kpms.load_checkpoint(PROJECT_DIR, model_name)
    results = kpms.extract_results(model, metadata, PROJECT_DIR, model_name)
# Out:
# Fitting model 0
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-0
#  49%|█████████████████▏                 | 25/51 [02:10<02:11,  5.07s/it]
#  98%|██████████████████████████████████▎| 50/51 [04:18<00:05,  5.40s/it]
# 100%|███████████████████████████████████| 51/51 [04:24<00:00,  5.18s/it]
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-0
#   6%|█▉                                | 25/451 [02:52<42:38,  6.01s/it]
#  11%|███▊                              | 50/451 [05:20<37:55,  5.67s/it]
#  17%|█████▋                            | 75/451 [07:53<37:18,  5.95s/it]
#  22%|███████▎                         | 100/451 [10:21<32:52,  5.62s/it]
#  28%|█████████▏                       | 125/451 [12:49<32:24,  5.97s/it]
#  33%|██████████▉                      | 150/451 [15:21<30:20,  6.05s/it]
#  39%|████████████▊                    | 175/451 [17:48<27:41,  6.02s/it]
#  44%|██████████████▋                  | 200/451 [20:17<25:28,  6.09s/it]
#  50%|████████████████▍                | 225/451 [22:46<22:36,  6.00s/it]
#  55%|██████████████████▎              | 250/451 [25:16<20:03,  5.99s/it]
#  61%|████████████████████             | 275/451 [27:45<17:21,  5.92s/it]
#  67%|█████████████████████▉           | 300/451 [30:14<15:34,  6.19s/it]
#  72%|███████████████████████▊         | 325/451 [32:44<12:19,  5.87s/it]
#  78%|█████████████████████████▌       | 350/451 [35:12<09:59,  5.94s/it]
#  83%|███████████████████████████▍     | 375/451 [37:43<07:31,  5.94s/it]
#  89%|█████████████████████████████▎   | 400/451 [40:12<04:57,  5.83s/it]
#  94%|███████████████████████████████  | 425/451 [42:41<02:31,  5.82s/it]
# 100%|████████████████████████████████▉| 450/451 [45:12<00:05,  5.83s/it]
# 100%|█████████████████████████████████| 451/451 [45:19<00:00,  6.03s/it]
# Reindexing: 100%|███████████| 21/21 [00:04<00:00,  4.58model snapshot/s]
# Saved results to /mnt/d/Project/Keypoint-Moseq/my_models-0/results.h5
# Fitting model 1
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-1
#  49%|█████████████████▏                 | 25/51 [02:04<02:09,  4.99s/it]
#  98%|██████████████████████████████████▎| 50/51 [04:10<00:04,  4.98s/it]
# 100%|███████████████████████████████████| 51/51 [04:15<00:00,  5.02s/it]
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-1
#   6%|█▉                                | 25/451 [02:32<42:15,  5.95s/it]
#  11%|███▊                              | 50/451 [05:01<39:38,  5.93s/it]
#  17%|█████▋                            | 75/451 [07:33<37:47,  6.03s/it]
#  22%|███████▎                         | 100/451 [10:01<34:51,  5.96s/it]
#  28%|█████████▏                       | 125/451 [12:38<33:23,  6.14s/it]
#  33%|██████████▉                      | 150/451 [15:08<30:07,  6.00s/it]
#  39%|████████████▊                    | 175/451 [17:37<27:13,  5.92s/it]
#  44%|██████████████▋                  | 200/451 [20:14<25:32,  6.11s/it]
#  50%|████████████████▍                | 225/451 [22:46<22:28,  5.97s/it]
#  55%|██████████████████▎              | 250/451 [25:25<22:30,  6.72s/it]
#  61%|████████████████████             | 275/451 [27:56<17:49,  6.07s/it]
#  67%|█████████████████████▉           | 300/451 [30:31<16:13,  6.45s/it]
#  72%|███████████████████████▊         | 325/451 [33:10<12:55,  6.15s/it]
#  78%|█████████████████████████▌       | 350/451 [35:43<09:59,  5.94s/it]
#  83%|███████████████████████████▍     | 375/451 [38:21<07:41,  6.07s/it]
#  89%|█████████████████████████████▎   | 400/451 [40:52<04:58,  5.85s/it]
#  94%|███████████████████████████████  | 425/451 [43:30<02:48,  6.48s/it]
# 100%|████████████████████████████████▉| 450/451 [46:02<00:06,  6.00s/it]
# 100%|█████████████████████████████████| 451/451 [46:09<00:00,  6.14s/it]
# Reindexing: 100%|███████████| 21/21 [00:05<00:00,  4.17model snapshot/s]
# Saved results to /mnt/d/Project/Keypoint-Moseq/my_models-1/results.h5
# Fitting model 2
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-2
#  49%|█████████████████▏                 | 25/51 [02:08<02:31,  5.82s/it]
#  98%|██████████████████████████████████▎| 50/51 [04:20<00:04,  4.98s/it]
# 100%|███████████████████████████████████| 51/51 [04:26<00:00,  5.23s/it]
# /home/bezver/anaconda3/envs/keypoint_moseq/lib/python3.10/site-packages/keypoint_moseq/fitting.py:594: UserWarning:
#
# 'kappa' with <class 'int'> will be cast to <class 'float'>
# Outputs will be saved to /mnt/d/Project/Keypoint-Moseq/my_models-2
#   6%|█▉                                | 25/451 [02:31<41:11,  5.80s/it]
#  11%|███▊                              | 50/451 [05:01<38:20,  5.74s/it]
#  17%|█████▋                            | 75/451 [07:30<38:22,  6.12s/it]
#  22%|███████▎                         | 100/451 [10:00<36:48,  6.29s/it]
#  28%|█████████▏                       | 125/451 [12:30<32:23,  5.96s/it]
#  30%|█████████▊                       | 134/451 [13:25<33:38,  6.37s/it]
